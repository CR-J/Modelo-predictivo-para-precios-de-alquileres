# %% [markdown]
# Cargo las librerías:

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Cargo los datasets:

# %%
X_train = pd.read_csv('X_train_ns.csv')
del X_train['Unnamed: 0']
y_train = pd.read_csv('log_y_train.csv')
del y_train['Unnamed: 0']
y_test = pd.read_csv('log_y_test.csv')
del y_test['Unnamed: 0']

# %% [markdown]
# ## Histogramas de la variable objetivo, log("Price")

# %% [markdown]
# El primer histograma muestra como la variable objetivo se acumula en ciertas columnas. Esto es porque los precios tienden a ser enteros, y tienden a redondearse hacia ciertos valores, por ejemplo 99 en lugar de 100:

# %%
objetivo = list(list(np.array(y_train).reshape(1,-1))[0])
sns.histplot(objetivo,binwidth=0.01)
plt.xlabel('Logaritmo del precio por noche')
plt.show()

# %% [markdown]
# Repito el histograma con barras algo más anchas para que el histograma no se vea afectado por estas acumulaciones:

# %%
sns.histplot(objetivo,binwidth=0.25)
plt.xlabel('Logaritmo del precio por noche en train')
plt.show()

# %% [markdown]
# Compruebo que el logaritmo del precio se reparte de forma similar en train y en test comparando el histograma anterior (sobre train) con el siguiente (sobre test):

# %%
objetivot = list(list(np.array(y_test).reshape(1,-1))[0])
sns.histplot(objetivot,binwidth=0.25)
plt.xlabel('Logaritmo del precio por noche en test')
plt.show()

# %% [markdown]
# ## Relación de la variable objetivo frente al resto de variables

# %% [markdown]
# Los scatterplots de la variable objetivo log("Price") frente a las distintas variables predictoras me aportan información sobre sus relaciones.
#
# Además, he añadido las correlaciones entre log("Price") y las variables predictoras.
#
# Los gráficos están ordenados desde las variables predictoras con mayor información mutua a las variables predictoras con menor información mutua, con lo que se puede ver que la información mutua y la correlación no dan la misma importancia a las distintas variables: la correlación mide relaciones lineales, mientras que la información mutua mide cualquier tipo de relación, lineal o no.

# %%
# El siguiente código me permitirá emplear negrita al usar print:

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    
for var in X_train.columns:
    print("La correlación es de",
          color.BOLD+str(round(np.corrcoef(objetivo,list(np.array(X_train[var])))[0,1],2))+color.END,
         "entre la variable",color.BOLD+str(var)+color.END,"y el logaritmo del precio por noche.")
    sns.scatterplot(x=objetivo,
                y=list(np.array(X_train[var])),alpha=0.5)
    plt.xlabel('Logaritmo del precio por noche')
    plt.ylabel(var)
    plt.show()
# Out:
# La correlación es de 0.51 entre la variable PCA2_v2 y el logaritmo del precio por noche.
# La correlación es de 0.63 entre la variable PCA2 y el logaritmo del precio por noche.
# La correlación es de 0.65 entre la variable Room Type y el logaritmo del precio por noche.
# La correlación es de 0.61 entre la variable Accommodates y el logaritmo del precio por noche.
# La correlación es de 0.07 entre la variable Cluster y el logaritmo del precio por noche.
# La correlación es de 0.24 entre la variable Host Total Listings Count y el logaritmo del precio por noche.
# La correlación es de 0.48 entre la variable Bedrooms y el logaritmo del precio por noche.
# La correlación es de 0.23 entre la variable Calculated host listings count y el logaritmo del precio por noche.
# La correlación es de 0.24 entre la variable Host Listings Count y el logaritmo del precio por noche.
# La correlación es de 0.44 entre la variable Beds y el logaritmo del precio por noche.
# ...
